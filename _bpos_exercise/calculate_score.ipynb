# %%
import pandas as pd
from pathlib import Path

# %%
exercise_path = Path("/Users/abelluc/FAUbox/DigiKolleg/BPOS/Exercise/WS23_24_Results")

# %%
# Read in the data

# %%
assignment_list = ["Assignment_1", "Assignment_2", "Assignment_3", "Assignment_4", "Assignment_5", "Assignment_6"]

# %%
total = {}

# %%
for assignment in assignment_list:
    df = pd.read_excel(exercise_path / f"{assignment}.xlsx")

    print(assignment)

    try:
        assignment_df = df[["Login", 1]]
    except KeyError:
        assignment_df = df[["Login", "Test Results in Marks"]]
    assignment_df.columns = ["idm", "passed"]
    assignment_df.set_index("idm", inplace=True)
    assignment_df.replace("passed", "Passed", inplace=True)

    assignment_df["passed"] = assignment_df["passed"] == "Passed"

    total[assignment] = assignment_df
# Out:
# Assignment_1
# Assignment_2
# Assignment_3
# Assignment_4
# Assignment_5
# Assignment_6
# /var/folders/3_/6bdchgy93zggkgq8kw8gyssr0000gn/T/ipykernel_1033/2677028914.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assignment_df.replace("passed", "Passed", inplace=True)
# /var/folders/3_/6bdchgy93zggkgq8kw8gyssr0000gn/T/ipykernel_1033/2677028914.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assignment_df["passed"] = assignment_df["passed"] == "Passed"
# /var/folders/3_/6bdchgy93zggkgq8kw8gyssr0000gn/T/ipykernel_1033/2677028914.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assignment_df.replace("passed", "Passed", inplace=True)
# /var/folders/3_/6bdchgy93zggkgq8kw8gyssr0000gn/T/ipykernel_1033/2677028914.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assignment_df["passed"] = assignment_df["passed"] == "Passed"
# /var/folders/3_/6bdchgy93zggkgq8kw8gyssr0000gn/T/ipykernel_1033/2677028914.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assignment_df.replace("passed", "Passed", inplace=True)
# /var/folders/3_/6bdchgy93zggkgq8kw8gyssr0000gn/T/ipykernel_1033/2677028914.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assignment_df["passed"] = assignment_df["passed"] == "Passed"
# /var/folders/3_/6bdchgy93zggkgq8kw8gyssr0000gn/T/ipykernel_1033/2677028914.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assignment_df.replace("passed", "Passed", inplace=True)
# /var/folders/3_/6bdchgy93zggkgq8kw8gyssr0000gn/T/ipykernel_1033/2677028914.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assignment_df["passed"] = assignment_df["passed"] == "Passed"
# /var/folders/3_/6bdchgy93zggkgq8kw8gyssr0000gn/T/ipykernel_1033/2677028914.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assignment_df.replace("passed", "Passed", inplace=True)
# /var/folders/3_/6bdchgy93zggkgq8kw8gyssr0000gn/T/ipykernel_1033/2677028914.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assignment_df["passed"] = assignment_df["passed"] == "Passed"
# /var/folders/3_/6bdchgy93zggkgq8kw8gyssr0000gn/T/ipykernel_1033/2677028914.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assignment_df.replace("passed", "Passed", inplace=True)
# /var/folders/3_/6bdchgy93zggkgq8kw8gyssr0000gn/T/ipykernel_1033/2677028914.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assignment_df["passed"] = assignment_df["passed"] == "Passed"

# %%
total_df = pd.concat(total)

# %%
# convert dict to dataframe
total_df.index.names = ["assignment", "idm"]
total_df.sort_index(inplace=True, level=1)
total_df.reset_index(inplace=True)
total_df.dropna(inplace=True, how="any")

total_df.set_index(["idm", "assignment"], inplace=True)

# %%
total_df = total_df.unstack("assignment")

# %%
result = pd.DataFrame(total_df.count(axis=1), columns=["passed"])

# %%
result
# Out:
#            passed  bonus
# idm
# ac13atok        6    0.7
# al96amyg        1    0.0
# an46ykim        6    0.7
# ax73aqur        1    0.0
# bi30lojy        6    0.7
# fi89bipe        2    0.0
# fu40panu        3    0.0
# fy02myxa        2    0.0
# ga20lydi        2    0.0
# ga45wapo        2    0.0
# go63gaxo        3    0.0
# hu59vore        2    0.0
# ib35olyr        2    0.0
# je18kuta        1    0.0
# le79piqy        2    0.0
# lo82weta        4    0.0
# luca.abel       2    0.0
# ni24bere        1    0.0
# nu84byna        5    0.3
# ok62ihoc        6    0.7
# qo24gufe        6    0.7
# ry66cyfu        1    0.0
# sa58juwu        4    0.0
# se67myvy        6    0.7
# uh87yhit        5    0.3
# up38ijep        3    0.0
# uw34esul        1    0.0
# uz45uhal        5    0.3
# ve76kyxi        1    0.0
# vy30goxy        5    0.3
# wa94kejo        2    0.0
# we15jori        6    0.7
# we70xebi        6    0.7
# wo16keno        1    0.0
# xo62nyru        1    0.0
# yh07ajaw        6    0.7
# ys47ojus        2    0.0
# yt60ubym        2    0.0
# yz45eryf        2    0.0
# za67salo        3    0.0

# %%
# add new column where called bonus where 0.3 is put in where 5 assignments are passed and 0.7 if 6 assignments are passed
result["bonus"] = result["passed"].apply(lambda x: 0.3 if x == 5 else 0.7 if x == 6 else 0)

# %%
result.to_excel(exercise_path / "result_final.xlsx")
