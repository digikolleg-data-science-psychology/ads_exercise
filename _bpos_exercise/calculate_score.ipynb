# %%
import pandas as pd
from pathlib import Path

# %%
exercise_path = Path("/Users/abelluc/FAUbox/DigiKolleg/BPOS/Exercise/WS25_26_Results")

# %%
# Read in the data

# %%
assignment_list = ["Assignment_1", "Assignment_2", "Assignment_3", "Assignment_4", "Assignment_5", "Assignment_6"]

# %%
total = {}

# %%
for assignment in assignment_list:
    df = pd.read_excel(exercise_path / f"{assignment}.xlsx")

    print(assignment)

    try:
        assignment_df = df[["Login", 1]]
    except KeyError:
        assignment_df = df[["Login", "Test Results in Marks"]]
    assignment_df.columns = ["idm", "passed"]
    assignment_df.set_index("idm", inplace=True)
    assignment_df.replace("passed", "Passed", inplace=True)

    assignment_df["passed"] = assignment_df["passed"].str.lower() == "passed" # upper or lower case

    total[assignment] = assignment_df
# Out:
# Assignment_1
# Assignment_2
# Assignment_3
# Assignment_4
# Assignment_5
# /var/folders/3_/6bdchgy93zggkgq8kw8gyssr0000gn/T/ipykernel_16367/923978472.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assignment_df.replace("passed", "Passed", inplace=True)
# /var/folders/3_/6bdchgy93zggkgq8kw8gyssr0000gn/T/ipykernel_16367/923978472.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assignment_df["passed"] = assignment_df["passed"].str.lower() == "passed" # upper or lower case
# ...

# %%
total_df = pd.concat(total)

# %%
# convert dict to dataframe
total_df.index.names = ["assignment", "idm"]
total_df.sort_index(inplace=True, level=1)
total_df.reset_index(inplace=True)
total_df.dropna(inplace=True, how="any")

total_df.set_index(["idm", "assignment"], inplace=True)

# %%
total_df = total_df.unstack("assignment")

# %%
result = pd.DataFrame(total_df.count(axis=1), columns=["passed"])

# %%
result
# Out:
#           passed
# idm
# av52ugaz       5
# bu60fyhy       5
# du23bera       1
# ex22uwud       1
# fe54pebo       3
# ic51uciw       1
# ic73elez       5
# lo72fudi       2
# ni04wyka       5
# no73widi       4
# pa59rocy       5
# qa47dibu       5
# ti62tize       5
# tu21zavu       2
# us87opat       3
# yb43ogiz       4
# zu40pyxu       4

# %%
# add new column where called bonus where 0.3 is put in where 5 assignments are passed and 0.7 if 6 assignments are passed
result["bonus"] = result["passed"].apply(lambda x: 0.33 if x == 4 else 0.66 if x == 5 else 0)

# %%
result.to_excel(exercise_path / "result_final.xlsx")
# Out:
# /var/folders/3_/6bdchgy93zggkgq8kw8gyssr0000gn/T/ipykernel_16367/658786975.py:1: UserWarning: Pandas requires version '3.0.5' or newer of 'xlsxwriter' (version '1.4.5' currently installed).
#   result.to_excel(exercise_path / "result_final.xlsx")
