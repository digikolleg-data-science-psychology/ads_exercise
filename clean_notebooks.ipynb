# %%
import os
from pathlib import Path

# %%
# specify the assignment
assignment = "10-ml"

graded_path = Path("/Users/abelluc/Code/ads_exercise/course_directory/ads_exercise/autograded")

# %%
for student in os.listdir(graded_path):
    for file in graded_path.joinpath(student, assignment).glob("*.ipynb"):
        os.system(f"jq -M 'del(.metadata.widgets)' {file} | sponge {file}")
