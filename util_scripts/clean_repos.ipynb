# %%
gh auth refresh -h github.com -s delete_repo

# %%
./generate-repositories-list.sh digikolleg-data-science-psychology > repos_to_delete.csv

# %% [markdown]
# ! Remove ads_exercise and ads_lecture notebooks from list

# %%
./delete-repositories-from-list.sh repos_to_delete.csv
