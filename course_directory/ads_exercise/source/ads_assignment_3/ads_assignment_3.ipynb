# %% [markdown]
# # **Applied Data Science in Medicine & Psychology - Assignment 3**
# ---
# ***Deadline: dd.mm.2023, hh:mm:ss TODO***
# ### **General setup and submission**
# 1. Save an editable copy of this notebook to your Google Drive ``File > Save a copy in Drive`` and remove the automatically appended "Copy of" text. Do not change the file name.
# 2. Work on the assignment in the *copied* version of the notebook. Make sure that you **replace** all parts of the tasks indicated with *YOUR CODE HERE* and **raise NotImplementedError()** or *YOUR ANSWER HERE* with your solution.
# 3. If you do a break during the implementation, you can save the current status of your work in your repository following the submission instructions below. When continuing the assignment **do not** reaccept the assignment, this would overwrite your work done so far. Continue the assignment in the version of the notebook that you saved in your Google Drive (access from your Google Colab account) or your own repository.
# 4. After finishing the assignment, make sure everything runs as expected. To do that select in the menubar Runtime $\rightarrow$ Restart and run all. This will clear all your local variables and runs your notebook from the beginning.
# 5. Submit your assignment as follows:
#     * Save your notebook, click ``File > Save``
#     * Click ``File > Save a copy in GitHub``
#     * Select ``Applied Data Science in Medicine & Psychology/ads_assignment_3-<username>`` from the Repository drop-down menu
#     * Type ``ads_assignment_3.ipynb`` into the File path text box
#     * Optionally, you may enter a description into the "Commit message" text box (like: "solved task 1" or "ready for grading")
#     * Make sure that the "Include a link to Colaboratory" box is checked
#     * Press "Ok"
#     * A new tab or window should open up, displaying your submitted notebook within your GitHub repository

# %% [markdown]
# ### **Assignment Description**
# ***General description... TODO***
#
# #### **Assignment goals**
# You are going to learn the following things in this assignment:
# 1. ***TODO***
# 2. ***TODO***
#
# #### **Assignment point value**
# This assignment is worth a total (up to) ***X TODO*** point***(s) TODO***. If your code passes all of the manual and automatic tests you will receive full credit.

# %% [markdown]
# ### **Tasks**
# Make sure that you now work on your *copied* version of this assignment's notebook.

# %% [markdown]
# #### 1. Functions
# Functions are a set of instructions that perform a specific task within a program. They allow developers to modularize code and reuse it throughout the program. Functions can take arguments (inputs) and return values (outputs):
# ```
# def <function_name>(<arg_1>, ..., <arg_N>):
#     <instruction_1>
#     ...
#     <instruction_N>
#     return <value>
# ```
#
# ##### 1.1 Create a function called ``get_datatype`` that takes a variable called ``var`` as argument and returns the type of the variable:
# **Hint:** check the lecture slides for a suitable function. Test your solution with different datatypes.

# %%
### BEGIN SOLUTION
def get_datatype(var):
    return type(var)
### END SOLUTION

# %%
assert get_datatype(5) == int, "check if you return the data type itself and not an string representation or similar"
assert get_datatype("Hello, world!") == str, "check if you return the data type itself and not an string representation or similar"
### BEGIN HIDDEN TESTS
assert get_datatype([1, 2]) == list
assert get_datatype(True) == bool
assert get_datatype({1:2}) == dict
assert get_datatype(1.2) == float
assert get_datatype(None) is type(None)
### END HIDDEN TESTS

# %% [markdown]
# #### 2. Datatypes - Dictionary
# A dictionary is a type of data structure that stores key-value pairs. Each key in the dictionary is associated with a value:
# ```
# dict_1 = {
#     key_1: value_1,
#     key_2: value_2
# }
# ```
# While dictionary keys must be unique, dictionary values can be duplicated. To access the value associated with a particular key, you can use square brackets:
# ```
# dict_1[key_1]
# ```
# ##### 2.1 Create a dictionary called ``patient`` with the following key-value pairs:
# | key | value | datatype |
# | :- | :- | :- |
# |name|Jane|string|
# |height|167.3|float|
# |vegetarian|True|boolean|
# |allergies|pollen, peanuts|list|
# |blood_test_results|None|Null|

# %%
### BEGIN SOLUTION
patient = {
    "name": "Jane",
    "height": 167.3,
    "vegetarian": True,
    "allergies": ["pollen", "peanuts"],
    "blood_test_results": None
}
### END SOLUTION

# %%
assert patient
assert patient["name"] == "Jane", "check the lecture slides how to create values of certain datatypes. Make sure that you use the correct datatype for the keys"
### BEGIN HIDDEN TESTS
assert patient["height"] == 167.3
assert patient["vegetarian"]
assert patient["allergies"] == ["pollen", "peanuts"]
assert patient["blood_test_results"] == None
### END HIDDEN TESTS

# %% [markdown]
# ##### 2.2 Add a key-value pair to the ``patient`` dictionary:
# | key | value | datatype |
# | :- | :- | :- |
# |age|24|int|
#
# **Hint:** you can add a key-value pair by using the accessing strategy described above and assigning a value to the specified key.

# %%
### BEGIN SOLUTION
patient["age"] = 24
### END SOLUTION
print(patient)
# Out:
# {'name': 'Jane', 'height': 167.3, 'vegetarian': True, 'allergies': ['pollen', 'peanuts'], 'blood_test_results': None, 'age': 24}

# %%
assert patient["age"], "check if you added the key-value pair correctly"
### BEGIN HIDDEN TESTS
assert patient["age"] == 24
### END HIDDEN TESTS

# %% [markdown]
# ##### 2.3 Create another dictionary called ``blood_test_results`` and assign it to the ``blood_test_results`` key of ``patient``:
# | key | value | datatype |
# | :- | :- | :- |
# |hemoglobin|13.6|float|
# |potassium|4.5|float|

# %%
### BEGIN SOLUTION
blood_test_results = {
    "hemoglobin": 13.6,
    "potassium": 4.5
}
patient["blood_test_results"] = blood_test_results
### END SOLUTION
print(patient)
# Out:
# {'name': 'Jane', 'height': 167.3, 'vegetarian': True, 'allergies': ['pollen', 'peanuts'], 'blood_test_results': {'hemoglobin': 13.6, 'potassium': 4.5}, 'age': 24}

# %%
assert blood_test_results
assert len(blood_test_results) == 2, "check if you added both elements to the dictionary"
### BEGIN HIDDEN TESTS
assert patient["blood_test_results"] == {
    "hemoglobin": 13.6,
    "potassium": 4.5
}
### END HIDDEN TESTS

# %% [markdown]
# #### 3. Datatypes - List
# A Python list is a structure that allows you to store a collection of elements of any data type in a single variable, like
# ```
# python_list = [12, "hello", 23.5, 25]
# ```
#
# | functionality | key word|explanation | example | return |
# | :- | :- | :- | :- | :- |
# |Accessing||access individual elements by their index, <br /> index starts from 0|``python_list[0]``|``12``|
# |Slicing||create a sub-list|``python_list[1:3]``|``["hello", 23.5]``|
# |Inserting|``insert``|insert a new element at a specific position|``python_list.insert(2, "new")`` | ``[12, "hello", "new", 23.5, 25]``
# |Deleting|``remove``|remove an element|``python_list.remove("hello")``|``[12, 23.5, 25]``|
# |Appending|``append``|add new elements to the end|``python_list.append([26, 27])``|``[12, "hello", 23.5, 25, [26, 27]]``|
# |Extending|``extend``|add new elements to the end|``python_list.extend([26, 27])``|``[12, "hello", 23.5, 25, 26, 27]``|
# |Membership|``in``|check if a particular element is present|``25 in python_list`` <br /> ``56 in python_list``|``True`` <br /> ``False``
#
# ##### 3.1 Create a list called ``my_list`` with the elements ``1, 2, "hello", 4, True``:

# %%
### BEGIN SOLUTION
my_list = [1, 2, "hello", 4, True]
### END SOLUTION

# %%
assert my_list
assert len(my_list) == 5, "check if you created the list with all the elements. Make sure that they are in the right order."
### BEGIN HIDDEN TESTS
assert my_list == [1, 2, "hello", 4, True]
### END HIDDEN TESTS

# %% [markdown]
# ##### 3.2 Create a variable ``result`` which adds the 2nd and 4th element of ``my_list`` using their index:

# %%
### BEGIN SOLUTION
result = my_list[1] + my_list[3]
### END SOLUTION

# %%
assert result
assert result == 6

# %% [markdown]
# ##### 3.3 Create a list ``sub_list`` which contains the 3rd, 4th, and 5th element of ``my_list`` using slicing:

# %%
### BEGIN SOLUTION
sub_list = my_list[2:5]
### END SOLUTION

# %%
assert sub_list
assert len(sub_list) == 3, "check the length of your sub_list and your indices. Did you consider how the last element is handled in slicing?"
### BEGIN HIDDEN TESTS
assert sub_list == ["hello", 4, True]
### END HIDDEN TESTS

# %% [markdown]
# ##### 3.4 Insert at the 4th position of ``new_list`` the string ``world``. Delete ``4`` out of ``new_list``:

# %%
new_list = my_list.copy()
print(new_list)

### BEGIN SOLUTION
new_list.insert(3, "world")
new_list.remove(4)
### END SOLUTION

print(new_list)

# %%
assert len(new_list) == 5, "check if you performed both operations (inserting, deleting)"
assert new_list[3] == "world", "check if you used the correct index for inserting"
### BEGIN HIDDEN TESTS
assert new_list == [1, 2, "hello", "world", True]
### END HIDDEN TESTS

# %% [markdown]
# ##### 3.5 Append ``tmp_list`` to ``new_list``:

# %%
tmp_list = [False, "hi", 3]
new_list = my_list.copy()

### BEGIN SOLUTION
new_list.append(tmp_list)
### END SOLUTION

print(new_list)
print(f"length of new_list: {len(new_list)}")

# %%
assert len(new_list) == 6, "the length of new_list must be 6"
### BEGIN HIDDEN TESTS
assert new_list == [1, 2, 'hello', 4, True, [False, 'hi', 3]]
### END HIDDEN TESTS

# %% [markdown]
# ##### 3.6 Extend ``new_list`` with ``tmp_list`` from above. Can you explain the difference between ``append`` and ``extend``?

# %%
new_list = my_list.copy()

### BEGIN SOLUTION
new_list.extend(tmp_list)
### END SOLUTION

print(new_list)
print(f"length of new_list: {len(new_list)}")

# %%
assert len(new_list) == 8, "the length of new_list must be 8"
### BEGIN HIDDEN TESTS
assert new_list == [1, 2, 'hello', 4, True, False, 'hi', 3]
### END HIDDEN TESTS

# %% [markdown]
# ##### 3.7 Create 2 variables
# * ``var_1``: checks whether ``my_list`` contains "hello, world!"
# * ``var_2``: checks whether ``my_list`` contains 4

# %%
### BEGIN SOLUTION
var_1 = "hello, world!" in my_list
var_2 = 4 in my_list
### END SOLUTION

print(var_1)
print(var_2)

# %%
assert type(var_1) == bool
assert type(var_2) == bool
### BEGIN HIDDEN TESTS
assert var_1 == False
assert var_2 == True
### END HIDDEN TESTS

# %% [markdown]
# #### 4. if statement
# An if statement is a control flow statement that allows you to execute a certain block of code only if a particular condition evaluates to true.
# ##### 4.1 Create an if - elif - else statement that checks whether a variable is equal to, greater, or less than 0. To do so:
# * create a variable called ``x`` and assign it to -5
# * if x is equal to 0: print "x is equal to 0"
# * if x is less than 0: print "x is negative"
# * if x is greater than 0: print "x is positive"
# * play around with different values for x

# %%
### BEGIN SOLUTION
x = -5
if x == 0:
    print("x is equal to 0")
elif x < 0:
    print("x is negative")
else:
    print("x is positive")
### END SOLUTION
# Out:
# x is negative

# %% [markdown]
# ##### 4.2 Implement a function that checks the potassium level of a person. The potassium level is usually between 3.7 and 5.3 mEq/l (milliequivalents per liter). To do so:
# * create a function called ``check_potassium`` that takes ``value`` as an argument
# * check if ``value`` is in the given normal potassium range
#     * if yes: print an informative message (e.g. "the potassium level is in the correct range") and return True
#     * if no: print an informative message and return False
# * Play around with different values to see if your implementation works correctly
#
# **Hint:** You can combine two conditions using logical operators. Also, you can create a variable to store your return value temporarily.

# %%
### BEGIN SOLUTION
def check_potassium(value):
    correct_range = True
    if value >= 3.7 and value <= 5.3:
        print("the potassium level is in the correct range")
    else:
        correct_range = False
        print("the potassium level is out of range")
    return correct_range
### END SOLUTION

# %%
assert check_potassium(4.0) == True, "check if you used the correct potassium range"
### BEGIN HIDDEN TESTS
assert check_potassium(3.0) == False
assert check_potassium(6.0) == False
### END HIDDEN TESTS
# Out:
# the potassium level is in the correct range
# the potassium level is out of range
# the potassium level is out of range

# %% [markdown]
# ##### 4.3 Implement a function that checks the hemoglobin level based on the age of the person. Assume the hemoglobin levels to be as follows:
# * 0 - 18 years: 10 - 15.5 g/dl (grams per deciliter)
# * \> 18 years: 12 - 18 g/dl (grams per deciliter)
#
# To do so:
# * create a function called ``check_hemoglobin`` that takes ``age`` and ``value`` as arguments
# * create a nested if-construct
#     * outer if-statement checks the range of ``age``
#     * inner if-statements checks based on the age the correct range of hemoglobin level
#         * if it is in the correct range print an informative message and return True
#         * if it is **not** in the correct range print an informative message and return False

# %%
### BEGIN SOLUTION
def check_hemoglobin(age, value):
    correct_range = True
    if age <= 18:
        if value >= 10 and value <= 15.5:
            print("the hemoglobin level is in the correct range")
        else:
            correct_range = False
            print("the hemoglobin level is out of range")
    else:
        if value >= 12 and value <= 18:
            print("the hemoglobin level is in the correct range")
        else:
            correct_range = False
            print("the hemoglobin level is out of range")
    return correct_range
### END SOLUTION

# %%
assert check_hemoglobin(16, 16.0) == False, "check if you used the correct hemoglobin range for underage people"
assert check_hemoglobin(23, 16.0) == True, "check if you used the correct hemoglobin range for adult people"
### BEGIN HIDDEN TESTS
assert check_hemoglobin(16, 13.0) == True
assert check_hemoglobin(16, 9.0) == False
assert check_hemoglobin(23, 19.0) == False
assert check_hemoglobin(23, 11.0) == False
### END HIDDEN TESTS
# Out:
# the hemoglobin level is out of range
# the hemoglobin level is in the correct range
# the hemoglobin level is in the correct range
# the hemoglobin level is out of range
# the hemoglobin level is out of range
# the hemoglobin level is out of range

# %% [markdown]
# #### 5. Loops
# Loops are a way to execute a block of code repeatedly. There are typically two types of loops:
# 1. For loops allow you to iterate over a sequence of elements (such as a list or range of numbers) and execute a block of code for each element in the sequence.
# 2. While loops allow you to execute a block of code repeatedly while a certain condition is true.
# ##### 5.1 Create a function ``calc_sum`` that takes a list of values as argument ``values`` as input. Then calculate the sum of the list entries using a for loop:
# **Hint:** Initialize a variable ``sum`` before the loop and assign it to 0. Test you solution with ``numbers``.

# %%
numbers = [23, 27, 21, 19]

### BEGIN SOLUTION
def calc_sum(values):
    sum = 0
    for i in values:
        sum += i
    return sum
### END SOLUTION

# %%
numbers = [23, 27, 21, 19]
assert calc_sum(numbers) == 90, "check your for loop syntax and used operator"
### BEGIN HIDDEN TESTS
assert calc_sum([0]) == 0
assert calc_sum([12, -12]) == 0
### END HIDDEN TESTS

# %% [markdown]
# ##### 5.2 It is also possible to iterate over keys, values, and key-value pairs of a dictionary using a for loop. You can access them like in the following:
# ```
# <dict>.keys() # get all the keys of dictionary <dict>
# <dict>.values() # get all the values of dictionary <dict>
# <dict>.items() # get all the key-value pairs of dictionary <dict>
# ```
# Create a for loop that iterates over and all keys of your dictionary ``patient`` and prints them. Then try the same for all values and items:

# %%
### BEGIN SOLUTION
for i in patient.keys():
    print(i)
### END SOLUTION
# Out:
# name
# height
# vegetarian
# allergies
# blood_test_results
# age

# %% [markdown]
# ##### 5.3 Create a function ``arange`` which generates lists of ascending numbers using a while loop. It takes the following arguments:
# * ``start``: start of the interval, included
# * ``stop``: stop of the interval, excluded
# * ``step``: spacing between values
#
# To do so:
# * create a control variable ``n`` and initialize it with ``start``
# * initilize an empty list ``numbers``
# * create the while loop such that it checks the current value of ``n`` and runs until ``stop``
# * append ``n`` to ``list_numbers``
# * add ``step`` in every iteration to your control variable.
# * return ``list_numbers``

# %%
### BEGIN SOLUTION
def arange(start, stop, step):
    numbers = []
    n = start
    while n < stop:
        numbers.append(n)
        n += step
    return numbers
### END SOLUTION

# %%
assert arange(5, 10, 1) == [5, 6, 7, 8, 9], "check if you set start and stop correctly, used the right operator, and performed all steps in the right order"
assert arange(5, 10, 2) == [5, 7, 9], "check if you set start and stop correctly, used the right operator, and performed all steps in the right order"
### BEGIN HIDDEN TESTS
assert arange(-6, 5, 3) == [-6, -3, 0, 3]
### END HIDDEN TESTS

# %% [markdown]
# #### 6. Typecasting
# Typecasting, also known as type conversion, is the process of converting a value of one data type to another data type. This can be useful in programming when you want to perform operations that require values of a specific data type.
#
# ##### 6.1 Convert the following variables to the specified data types:
# * x from ``float`` to ``int``
# * y from ``float`` to ``bool``
# * z from ``int`` to ``float``

# %%
x = 8.7
y = 1.0
z = 9

### BEGIN SOLUTION
x = int(x)
y = bool(y)
z = float(z)
### END SOLUTION

print(x)
print(y)
print(z)

# %%
assert type(x) == int, "check if you converted x to the correct data type"
assert type(y) == bool, "check if you converted y to the correct data type"
assert type(z) == float, "check if you converted z to the correct data type"
### BEGIN HIDDEN TESTS
assert x == 8
assert y
assert z == 9.0
### END HIDDEN TESTS
