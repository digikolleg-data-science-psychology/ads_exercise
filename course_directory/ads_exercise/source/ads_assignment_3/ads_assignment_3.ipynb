# %% [markdown]
# # **Applied Data Science in Medicine & Psychology - Assignment 3**
# ---
# ***Deadline: dd.mm.2023, hh:mm:ss TODO***
# ### **General setup and submission**
# 1. Save an editable copy of this notebook to your Google Drive ``File > Save a copy in Drive`` and remove the automatically appended "Copy of" text. Do not change the file name.
# 2. Work on the assignment in the *copied* version of the notebook. Make sure that you replace all parts of the tasks indicated with *YOUR CODE HERE* and **raise NotImplementedError()** or *YOUR ANSWER HERE* with your solution.
# 3. If you do a break during the implementation, you can save the current status of your work in your repository following the submission instructions below. When continuing the assignment **do not** reaccept the assignment, this would overwrite your work done so far. Continue the assignment in the version of the notebook that you saved in your Google Drive (access from your Google Colab account) or your own repository.
# 4. After finishing the assignment, make sure everything runs as expected. To do that select in the menubar Runtime $\rightarrow$ Restart and run all. This will clear all your local variables and runs your notebook from the beginning.
# 5. Submit your assignment as follows:
#     * Save your notebook, click ``File > Save``
#     * Click ``File > Save a copy in GitHub``
#     * Select ``Applied Data Science in Medicine & Psychology/ads_assignment_3-<username>`` from the Repository drop-down menu
#     * Type ``ads_assignment_3.ipynb`` into the File path text box
#     * Optionally, you may enter a description into the "Commit message" text box (like: "solved task 1" or "ready for grading")
#     * Make sure that the "Include a link to Colaboratory" box is checked
#     * Press "Ok"
#     * A new tab or window should open up, displaying your submitted notebook within your GitHub repository

# %% [markdown]
# ### **Assignment Description**
# ***General description... TODO***
#
# #### **Assignment goals**
# You are going to learn the following things in this assignment:
# 1. ***TODO***
# 2. ***TODO***
#
# #### **Assignment point value**
# This assignment is worth a total (up to) ***X TODO*** point***(s) TODO***. If your code passes all of the manual and automatic tests you will receive full credit.

# %% [markdown]
# ### **Tasks**
# Make sure that you now work on your *copied* version of this assignment's notebook.

# %% [markdown]
# #### 0. Imports and Setup
# Please **run** the cell below to import the libraries needed for this assignment.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### 1. Functions
# Functions are a set of instructions that perform a specific task within a program. They allow developers to modularize code and reuse it throughout the program. Functions can take arguments (inputs) and return values (outputs)
# ```
# def <function_name>(<arg_1>, ..., <arg_N>):
#     <instruction_1>
#     ...
#     <instruction_N>
#     return <value>
# ```
#
# ##### 1.1 Create a function called ``get_datatype`` that takes a variable called ``var`` as argument, prints and returns the type of the variable:
# **Hint:** check the lecture slides for a suitable function. Test your solution with different datatypes.

# %%
### BEGIN SOLUTION
def get_datatype(var):
    return type(var)
### END SOLUTION

# %%
assert get_datatype(5) == int
assert get_datatype("Hello, world!") == str
### BEGIN HIDDEN TESTS
assert get_datatype([1, 2]) == list
assert get_datatype(True) == bool
### END HIDDEN TESTS

# %% [markdown]
# #### 2. Datatypes
# A dictionary is a type of data structure that stores key-value pairs. Each key in the dictionary is associated with a value:
# ```
# dict_1 = {
#     key_1: value_1,
#     key_2: value_2
# }
# ```
# While dictionary keys must be unique, dictionary values can be duplicated. To access the value associated with a particular key, you can use square brackets:
# ```
# dict_1[key_1]
# ```
# ##### 2.1 Create a dictionary called ``patient_1`` with the following key-value pairs:
# | key | value | datatype |
# | :- | :- | :- |
# |name|John|string|
# |age|35|int|
# |weight|78.4|float|
# |vegetarian|True|boolean|
# |allergies|pollen, peanuts|list|
# |blood_test_results|None|Null|
#
# **Hint**: check the lecture slides how to create values of certain datatypes. Make sure that you use the correct datatype for the keys.

# %%
### BEGIN SOLUTION
patient_1 = {
    "name": "John",
    "age": 35,
    "weight": 78.4,
    "vegetarian": True,
    "allergies": ["pollen", "peanuts"],
    "blood_test_results": None
}
### END SOLUTION

# %%
assert patient_1
### BEGIN HIDDEN TESTS
assert patient_1["name"] == "John"
assert patient_1["age"] == 35
assert patient_1["weight"] == 78.4
assert patient_1["vegetarian"]
assert patient_1["allergies"] == ["pollen", "peanuts"]
assert patient_1["blood_test_results"] == None
### END HIDDEN TESTS

# %% [markdown]
# ##### 2.2 Add a key-value pair to the ``patient_1`` dictionary:
# | key | value | datatype |
# | :- | :- | :- |
# |sex|male|string|
#
# **Hint:** you can add a key-value pair simply by using the accessing strategy described above and assigning a value to the specified key.

# %%
### BEGIN SOLUTION
patient_1["sex"] = "male"
### END SOLUTION
print(patient_1)
# Out:
# {'name': 'John', 'age': 35, 'weight': 78.4, 'vegetarian': True, 'allergies': ['pollen', 'peanuts'], 'blood_test_results': {'hemoglobin': 13.6, 'potassium': 4.5}, 'sex': 'male'}

# %%
assert patient_1
### BEGIN HIDDEN TESTS
assert patient_1["sex"] == "male"
### END HIDDEN TESTS

# %% [markdown]
# ##### 2.3 Create another dictionary called ``blood_test_results`` and assign to the ``blood_test_results`` key of ``patient_1``:
# | key | value | datatype |
# | :- | :- | :- |
# |hemoglobin|13.6|float|
# |potassium|4.5|float|

# %%
### BEGIN SOLUTION
blood_test_results = {
    "hemoglobin": 13.6,
    "potassium": 4.5
}
patient_1["blood_test_results"] = blood_test_results
### END SOLUTION
print(patient_1)
# Out:
# {'name': 'John', 'age': 35, 'weight': 78.4, 'vegetarian': True, 'allergies': ['pollen', 'peanuts'], 'blood_test_results': {'hemoglobin': 13.6, 'potassium': 4.5}, 'sex': 'male'}

# %%
assert blood_test_results
### BEGIN HIDDEN TESTS
assert patient_1["blood_test_results"] == {
    "hemoglobin": 13.6,
    "potassium": 4.5
}
### END HIDDEN TESTS

# %%
patient_1
# Out:
# {'name': 'John',
#  'age': 35,
#  'weight': 78.4,
#  'vegetarian': True,
#  'allergies': ['pollen', 'peanuts'],
#  'blood_test_results': {'hemoglobin': 13.6, 'potassium': 4.5},
#  'sex': 'male'}

# %% [markdown]
# #### 3. if statement
# An if statement is a control flow statement that allows you to execute a certain block of code only if a particular condition evaluates to true.
# ##### 3.1 Create an if - elif - else statement that checks whether a variable is equal to, greater, or less than 0. To do so:
# * create a variable called ``x`` and assign it to -5
# * if x is equal to 0: print "x is equal to 0"
# * if x is less than 0: print "x is negative"
# * if x is greater than 0: print "x is positive"
# * play around with different values for x

# %%
### BEGIN SOLUTION
x = -5
if x == 0:
    print("x is equal to 0")
elif x < 0:
    print("x is negative")
else:
    print("x is positive")
### END SOLUTION
# Out:
# x is negative

# %% [markdown]
# ##### 3.2 Implement a function that checks the potassium level of a patient. The potassium level is usually between 3.7 and 5.3 mEq/l (milliequivalents per liter). To do so:
# * create a function called ``check_potassium`` that takes ``value`` as an argument
# * check if ``value`` is in the given normal potassium range
#     * if yes: print an informative message (e.g. "the potassium level is in the correct range") and return False
#     * if no: print an informative message and return True
# * Play around with different value to see if your implementation works correctly
#
# **Hint:** You can combine two conditions using logical operators.

# %%
### BEGIN SOLUTION
def check_potassium(value):
    further_actions = False
    if value >= 3.7 and value <= 5.3:
        print("the potassium level is in the correct range")
    else:
        further_actions = True
        print("the potassium level is out of range")
    return further_actions
### END SOLUTION

# %%
assert check_potassium(4.0) == False
### BEGIN HIDDEN TESTS
assert check_potassium(3.0) == True
assert check_potassium(6.0) == True
### END HIDDEN TESTS
# Out:
# the potassium level is in the correct range
# the potassium level is out of range
# the potassium level is out of range

# %% [markdown]
# ##### 3.3 Implement a function that checks the hemoglobin level based on the sex of the patient. The hemoglobin level of females is usually between 12.1 and 15.1 g/dl (grams per deciliter), for males it lays between 13.8 and 17.2 g/dl. To do so:
# * create a function called ``check_hemoglobin`` that takes ``sex`` and ``value`` as arguments
# * create a nested if-construct
#     * outer if-statement checks if ``sex`` is female or male
#     * inner if-statements checks based on the sex the correct range of hemoglobin level
#         * if it is in range print an informative message and return False
#         * if it is **not** in the correct range print an informative message and return True

# %%
### BEGIN SOLUTION
def check_hemoglobin(sex, value):
    further_actions = False
    if sex == "female":
        if value >= 12.1 and value <= 15.1:
            print("the hemoglobin level is in the correct range")
        else:
            further_actions = True
            print("the hemoglobin level is out of range")
    elif sex == "male":
        if value >= 13.8 and value <= 17.2:
            print("the hemoglobin level is in the correct range")
        else:
            further_actions = True
            print("the hemoglobin level is out of range")
    return further_actions
### END SOLUTION

# %%
assert check_hemoglobin("female", 16.0) == True
assert check_hemoglobin("male", 16.0) == False
### BEGIN HIDDEN TESTS
assert check_hemoglobin("female", 13.0) == False
assert check_hemoglobin("female", 12.0) == True
assert check_hemoglobin("male", 13.0) == True
assert check_hemoglobin("male", 18.0) == True
### END HIDDEN TESTS
# Out:
# the hemoglobin level is out of range
# the hemoglobin level is in the correct range
# the hemoglobin level is in the correct range
# the hemoglobin level is out of range
# the hemoglobin level is out of range
# the hemoglobin level is out of range

# %% [markdown]
# #### 4. Loops
# Loops are a way to execute a block of code repeatedly. There are typically two types of loops:
# 1. For loops allow you to iterate over a sequence of elements (such as a list or range of numbers) and execute a block of code for each element in the sequence.
# 2. While loops allow you to execute a block of code repeatedly while a certain condition is true.
# ##### 4.1 Create a

# %%
def print_numbers(max):
    for i in range(max+1):
        print(i)
        
print_numbers(4)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# Iterable: You can iterate over the keys, values, or items (key-value pairs) of a dictionary using a for loop.
#
# * Typecasting
#     * print(type(variable))
# * Loops
#     * for
#     * while
#     * nested loops
# * importing new functions
#     * from
#     * as
# * getting help
#     * help(m.sin)

# %% [markdown]
# **TODO ...**

# %% [markdown]
# === BEGIN MARK SCHEME ===
# Manually graded task
# === END MARK SCHEME ===

# %%
### BEGIN SOLUTION
### END SOLUTION

# %%
### BEGIN HIDDEN TESTS
### END HIDDEN TESTS
