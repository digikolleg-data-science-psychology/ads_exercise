# %% [markdown]
# gh auth refresh -h github.com -s delete_repo

# %% [markdown]
# ./generate-repositories-list.sh digikolleg-data-science-psychology > repos.csv

# %% [markdown]
# ./delete-repositories-from-list.sh repos.csv
